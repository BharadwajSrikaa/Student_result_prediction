# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("./StudentsPerformance.csv")

# %%
print(df.head())
print()
print(df.columns)
print()
print(df.dtypes)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')
#
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
print(df.head())
print()
print(df.columns)
print()
print(df.dtypes)
# Out:
#    math score  reading score  writing score  gender_male  \
# 0          72             72             74        False
# 1          69             90             88        False
# 2          90             95             93        False
# 3          47             57             44         True
# 4          76             78             75         True
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                    True                   False                   False
# 1                   False                    True                   False
# 2                    True                   False                   False
# 3                   False                   False                   False
# 4                   False                    True                   False
#
#    race/ethnicity_group E  parental level of education_bachelor's degree  \
# 0                   False                                           True
# 1                   False                                          False
# 2                   False                                          False
# 3                   False                                          False
# 4                   False                                          False
#
#    parental level of education_high school  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    parental level of education_master's degree  \
# 0                                        False
# 1                                        False
# 2                                         True
# 3                                        False
# 4                                        False
#
#    parental level of education_some college  \
# 0                                     False
# 1                                      True
# 2                                     False
# 3                                     False
# 4                                      True
#
#    parental level of education_some high school  lunch_standard  \
# 0                                         False            True
# 1                                         False            True
# 2                                         False            True
# 3                                         False           False
# 4                                         False            True
#
#    test preparation course_none
# 0                          True
# 1                         False
# 2                          True
# 3                          True
# 4                          True
#
# Index(['math score', 'reading score', 'writing score', 'gender_male',
#        'race/ethnicity_group B', 'race/ethnicity_group C',
#        'race/ethnicity_group D', 'race/ethnicity_group E',
#        'parental level of education_bachelor's degree',
#        'parental level of education_high school',
#        'parental level of education_master's degree',
#        'parental level of education_some college',
#        'parental level of education_some high school', 'lunch_standard',
#        'test preparation course_none'],
#       dtype='object')
#
# math score                                       int64
# reading score                                    int64
# writing score                                    int64
# gender_male                                       bool
# race/ethnicity_group B                            bool
# race/ethnicity_group C                            bool
# race/ethnicity_group D                            bool
# race/ethnicity_group E                            bool
# parental level of education_bachelor's degree     bool
# parental level of education_high school           bool
# parental level of education_master's degree       bool
# parental level of education_some college          bool
# parental level of education_some high school      bool
# lunch_standard                                    bool
# test preparation course_none                      bool
# dtype: object

# %%
X = df.drop(["math score"], axis = 1)
y = df["math score"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
model = LinearRegression()
model.fit(X_train, y_train)

print("Accuracy: ", model.score(X_test, y_test))
# Out:
# Accuracy:  0.8786411839957854

# %%
# Used to know the weight values of the variables
for feature, coef in zip(X.columns, model.coef_):
    print(feature, ":", coef)
# Out:
# reading score : 0.2660095154870568
# writing score : 0.708334136875225
# gender_male : 13.554161880341399
# race/ethnicity_group B : 0.8753906042495788
# race/ethnicity_group C : -0.28660973244805005
# race/ethnicity_group D : -0.17067002147622307
# race/ethnicity_group E : 4.7970074149286885
# parental level of education_bachelor's degree : -1.1206577727438327
# parental level of education_high school : 0.6334713429377525
# parental level of education_master's degree : -1.7001751194984907
# parental level of education_some college : 0.5459777431971972
# parental level of education_some high school : 0.41117578027279367
# lunch_standard : 2.9446487267098553
# test preparation course_none : 3.635374500203794

# %%
# We are Dropping gender Because it is insignificant when it come to math score in practical situation
X = X.drop(["gender_male"], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
model = LinearRegression()
model.fit(X_test, y_test)
print("Accuracy: ", model.score(X_test, y_test))
# Out:
# Accuracy:  0.730611317146246

# %%
for feature, coef in zip(X.columns, model.coef_):
    print(feature, ":", coef)
# Out:
# reading score : 0.5397103446992011
# writing score : 0.2953874478455063
# race/ethnicity_group B : 3.155951792395395
# race/ethnicity_group C : 1.326278509372531
# race/ethnicity_group D : 3.355903757804536
# race/ethnicity_group E : 7.182900464790741
# parental level of education_bachelor's degree : 0.2061936114464837
# parental level of education_high school : 0.10603729310491064
# parental level of education_master's degree : -1.4675427262278142
# parental level of education_some college : -0.5941397150909403
# parental level of education_some high school : -1.3498201350794135
# lunch_standard : 5.88308807577425
# test preparation course_none : 2.0829304950235614
